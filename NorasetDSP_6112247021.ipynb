# %%
#Lab01 ประกาศตัวแปล
from __future__ import print_function, division

# %matplotlib inline

import thinkdsp
import thinkplot

import numpy as np

from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
from IPython.display import display
sin_sig = thinkdsp.SinSignal(freq=7021, amp=21, offset=0)
sin_sig.plot()
thinkplot.config(xlabel='Time (s)')

# %%
#lab02
signal = thinkdsp.TriangleSignal(4000)
duration = signal.period*2500
segment = signal.make_wave(duration, framerate=10000)
segment.plot()
Mwave = signal.make_wave(duration, framerate = 10000)

spectrum = wave.make_spectrum()
spectrum.plot()

Mwave.apodize()
Mwave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
signalSQ = thinkdsp.SquareSignal(4000)
duration = signalSQ.period*2500
segment = signalSQ.make_wave(duration, framerate=10000)
segment.plot()

Mwave = signalSQ.make_wave(duration, framerate = 10000)

spectrum = wave.make_spectrum()
spectrum.plot()

Mwave.apodize()
Mwave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
